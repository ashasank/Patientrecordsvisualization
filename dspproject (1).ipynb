# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\hp\Downloads\\patient.csv")

# %%
df
# Out:
#                      id  gender         dob  zipcode employment_status  \
# 0          Amelia Nixon  female  1944-03-09    89136           retired
# 1           Clara Hicks  female  1966-07-02    94105          employed
# 2           Mason Brown    male  1981-05-31    89127          employed
# 3          Michael Rice    male  1945-02-13    44101           retired
# 4        Eleanor Ritter  female  1939-09-03    89136           retired
# ...                 ...     ...         ...      ...               ...
# 1995      Ethan Johnson    male  1942-04-13    89127           retired
# 1996  Natalia Dominguez  female  1963-05-10    60612        unemployed
# 1997      Joseph Zuniga    male  1965-07-12    94110          employed
# 1998      Daniel Murphy    male  1926-08-10    90015           retired
# 1999      Samuel Harris    male  1948-11-22    43210           retired
#
#        education marital_status  children     ancestry  avg_commute  \
# ...

# %%
df.shape
# Out:
# (2000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  2000 non-null   object
#  1   gender              2000 non-null   object
#  2   dob                 2000 non-null   object
#  3   zipcode             2000 non-null   int64
#  4   employment_status   2000 non-null   object
#  5   education           2000 non-null   object
#  6   marital_status      2000 non-null   object
#  7   children            2000 non-null   int64
#  8   ancestry            2000 non-null   object
#  9   avg_commute         2000 non-null   float64
#  10  daily_internet_use  2000 non-null   float64
#  11  available_vehicles  2000 non-null   int64
#  12  military_service    2000 non-null   object
#  13  disease             2000 non-null   object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 218.9+ KB

# %%
df.head()
# Out:
#                id  gender         dob  zipcode employment_status  education  \
# 0    Amelia Nixon  female  1944-03-09    89136           retired  bachelors
# 1     Clara Hicks  female  1966-07-02    94105          employed     phd/md
# 2     Mason Brown    male  1981-05-31    89127          employed    masters
# 3    Michael Rice    male  1945-02-13    44101           retired  bachelors
# 4  Eleanor Ritter  female  1939-09-03    89136           retired    masters
#
#   marital_status  children  ancestry  avg_commute  daily_internet_use  \
# 0        married         1  Portugal        13.38                2.53
# 1        married         4    Sweden        15.16                6.77
# 2        married         2   Germany        23.60                3.63
# 3        married         2   Denmark        19.61                5.00
# 4        married         3   Austria        36.55                7.75
#
#    available_vehicles military_service             disease
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# gender                0
# dob                   0
# zipcode               0
# employment_status     0
# education             0
# marital_status        0
# children              0
# ancestry              0
# avg_commute           0
# daily_internet_use    0
# available_vehicles    0
# military_service      0
# disease               0
# dtype: int64

# %%
df.describe()
# Out:
#             zipcode     children  avg_commute  daily_internet_use  \
# count   2000.000000  2000.000000  2000.000000         2000.000000
# mean   63387.827500     2.266500    30.376895            4.993325
# std    30165.490876     1.615792    10.026961            1.387846
# min    10001.000000     0.000000    -2.470000            1.010000
# 25%    43221.000000     1.000000    23.460000            4.020000
# 50%    60612.000000     2.000000    30.320000            5.010000
# 75%    90008.000000     3.000000    37.127500            5.972500
# max    94110.000000     7.000000    63.730000            8.820000
#
#        available_vehicles
# count         2000.000000
# mean             1.746000
# std              1.118977
# min              0.000000
# 25%              1.000000
# 50%              2.000000
# 75%              3.000000
# max              4.000000

# %%
df.columns
# Out:
# Index(['id', 'gender', 'dob', 'zipcode', 'employment_status', 'education',
#        'marital_status', 'children', 'ancestry', 'avg_commute',
#        'daily_internet_use', 'available_vehicles', 'military_service',
#        'disease'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='gender', data=df)
plt.title('Gender Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['daily_internet_use'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Daily Internet Use')
plt.ylabel('Count')
plt.title('Daily Internet Use Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['available_vehicles'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Available Vehicles')
plt.ylabel('')
plt.show()

# %%
df['dob'] = pd.to_datetime(df['dob'])
df['year'] = df['dob'].dt.year
yearly_counts = df['year'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
plt.plot(yearly_counts.index, yearly_counts.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Yearly Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='employment_status', y='avg_commute', data=df)
plt.title('Average Commute Time by Employment Status')
plt.ylabel('Average Commute Time')
plt.xlabel('Employment Status')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='daily_internet_use', y='avg_commute', data=df)
plt.title('Daily Internet Use vs. Average Commute Time')
plt.xlabel('Daily Internet Use')
plt.ylabel('Average Commute Time')
plt.show()

# %%
# Selecting numeric columns for correlation matrix
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_columns.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
employment_status_counts = df.groupby(['employment_status', 'gender']).size().unstack()
employment_status_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Gender Distribution by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='education', y='avg_commute', hue='employment_status', data=df)
plt.title('Average Commute Time by Education Level and Employment Status')
plt.xlabel('Education Level')
plt.ylabel('Average Commute Time')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='gender', y='daily_internet_use', data=df)
plt.title('Daily Internet Use Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Daily Internet Use')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a DataFrame named 'df'
# df = pd.read_csv('your_dataset.csv')

# Count the occurrences of each disease
disease_counts = df['disease'].value_counts()

# Bar Chart for Diseases
plt.figure(figsize=(10, 6))
disease_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Disease')
plt.ylabel('Count')
plt.title('Different Types of Diseases')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import pandas as pd

# Assuming your data is in a DataFrame named 'df'
# df = pd.read_csv('your_dataset.csv')

# Extract unique values from the 'disease' column
unique_diseases = df['disease'].unique()

# Display unique diseases
print("Different types of diseases present in the dataset:")
for disease in unique_diseases:
    print(disease)
# Out:
# Different types of diseases present in the dataset:
# hypertension
# endometriosis
# prostate cancer
# multiple sclerosis
# skin cancer
# Alzheimer's disease
# kidney disease
# breast cancer
# HIV/AIDS
# heart disease
# diabetes
# gastritis
# schizophrenia

# %%
grouped_data = df.groupby(['ancestry', 'disease'])['children'].sum().reset_index()

# Display the results
print("Children affected by different diseases in different countries:")
print(grouped_data)
# Out:
# Children affected by different diseases in different countries:
#     ancestry              disease  children
# 0    Austria  Alzheimer's disease        23
# 1    Austria             HIV/AIDS         8
# 2    Austria        breast cancer        32
# 3    Austria             diabetes        17
# 4    Austria        endometriosis         4
# ..       ...                  ...       ...
# 252  Ukraine       kidney disease         8
# 253  Ukraine   multiple sclerosis         9
# 254  Ukraine      prostate cancer        12
# 255  Ukraine        schizophrenia         7
# 256  Ukraine          skin cancer        20
#
# [257 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
for ancestry in grouped_data['ancestry'].unique():
    ancestry_data = grouped_data[grouped_data['ancestry'] == ancestry]
    plt.bar(ancestry_data['disease'], ancestry_data['children'], label=ancestry)

plt.xlabel('Disease')
plt.ylabel('Number of Children Affected')
plt.title('Children Affected by Different Diseases in Different Ancestries')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import folium
map_center = [df['zipcode'].mean(), df['zipcode'].mean()]  # Center the map based on the average of zip codes
map_zoom = 6
mymap = folium.Map(location=map_center, zoom_start=map_zoom)

# Add markers for military service 'Yes'
for index, row in df.iterrows():
    if row['military_service'] == 'Yes':
        folium.Marker(
            location=[row['zipcode'], row['zipcode']],
            popup=f"ID: {row['id']}<br>Military Service: {row['military_service']}",
            icon=folium.Icon(color='green')
        ).add_to(mymap)

# %%
mymap.save('military_service_map.html')

# %%
from IPython.display import IFrame

# Specify the path to the saved HTML file
html_file_path = 'military_service_map.html'

# Display the map in the Jupyter Notebook
IFrame(html_file_path, width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="military_service_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
numeric_columns = ['children', 'avg_commute', 'daily_internet_use', 'available_vehicles']

# Pair plot for the selected columns
sns.pairplot(df[numeric_columns])
plt.show()
